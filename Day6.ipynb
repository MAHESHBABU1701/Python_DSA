# %% [markdown]
# <a href="https://colab.research.google.com/github/MAHESHBABU1701/Python_DSA/blob/main/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Frequency  count
arr=list(map(int,input().split()))
dict={}
for i in arr:
    if i in dict:
        dict[i]+=1
    else:
        dict[i]=1
print(dict)
# Out:
# 2 2 3 6 4 2 3 4 6 5 1
# {2: 3, 3: 2, 6: 2, 4: 2, 5: 1, 1: 1}

# %%
# Find first non repeating element
arr=list(map(int,input().split()))
freq_dict={}
for i in arr:
  if i in freq_dict:
    freq_dict[i]+=1
  else:
    freq_dict[i]=1
for j in arr:
  if freq_dict[j]==1:
    print(j)
    break
# Out:
# 2 2 1 3 1 5 4 5
# 3

# %%
nums=[1,2,3,2,3,2,3,2,3]
dict1={}
k=3
for i in nums:
  if i in dict1:
    dict1[i]+=1
  else:
    dict1[i]=1
print(dict1)
a1=[]
for num,count in dict1.items():
  a1.append([count,num])
  arr.sort()
res=[]
while len(res)<k:
  res.append(a1.pop()[1])
print(res)
# Out:
# {1: 1, 2: 4, 3: 4}
# [3, 2, 1]

# %%
# Find duplicates and print
n11=list(map(int,input().split()))
d2={}
for i in n11:
  if i in d2:
    d2[i]+=1
  else:
    d2[i]=1
for j in d2:
  if d2[j]>1:
    print(j)
# Out:
# 2 3 1 2 5 4 6 3 2 1
# 2
# 3
# 1

# %%
# Find duplicates and print(using set)
n22=list(map(int,input().split()))
seen=set()
res=set()
for i in n22:
  if i not in seen:
    seen.add(i)
  else:
    res.add(i)
print(res)
# Out:
# 2 3 2 5 1  2 4 4 1 7 1 4 9
# {1, 2, 4}

# %%
def group_anagrams(strs):
    anagram_map = defaultdict(list)
    for word in strs:
        sorted_word = "".join(sorted(word))
        anagram_map[sorted_word].append(word)
    return list(anagram_map.values())

words = ["eat", "tea", "tan", "ate", "nat", "bat"]
result = group_anagrams(words)
print(result)

words2 = ["listen", "silent", "enlist", "hello", "world"]
result2 = group_anagrams(words2)
print(result2)
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]
# [['listen', 'silent', 'enlist'], ['hello'], ['world']]
